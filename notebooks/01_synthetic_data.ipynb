# %% [markdown]
# # 人工データ実験

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import csv

import os
import random
import itertools
from collections import defaultdict

# %%
# --- put this at the VERY TOP of your notebook ---
import sys
from pathlib import Path

# プロジェクト直下（= synthetic_data の親）を sys.path に追加
proj_root = Path.cwd().parent  # ← ノートが synthetic_data/ 内にある前提
sys.path.insert(0, str(proj_root))

# 動作確認
import importlib, pkgutil
assert any(p.name == "synthetic_data" for p in pkgutil.iter_modules([str(proj_root)])), "project root not found"

from src.experiments.trainer import train_model
from src.models.proposed import Model
from src.data.generate import generate_data
from src.utils.common import set_seed

# %%
# デバイス設定

use_cuda = torch.cuda.is_available()
use_mps = torch.backends.mps.is_available()

if use_cuda:
    device = torch.device("cuda")
# elif use_mps:
#     device = torch.device("mps")
else:
    device = torch.device("cpu")
    
print(f"CUDA available: {use_cuda}")
print(f"MPS available: {use_mps}")
print(f"Using device: {device}")
# Out:
# CUDA available: False
# MPS available: True
# Using device: cpu

# %% [markdown]
# ### 実験設定

# %%
from src.utils.common import get_args

args = get_args()
print('args:', args)

# %%
from src.utils.common import generate_grid_configs

configs = generate_grid_configs()

for i, c in enumerate(configs[:5]):
    print(f"[{i}] students={c['n_students']}, skills={c['n_skills']}, smoothing={c['smoothing']}, "
          f"alpha={c['alpha']}, beta={c['beta']}, growth_alpha={c['growth_alpha']}, growth_beta={c['growth_beta']}")

# %%
models_dict = {
    "proposed": None,
    "upper": None,
    "all": None,
    "population_base": None,
    "next_node": None,
    "uniform": None
}

from result import generate_header, ensure_csv_header, append_row, make_row, merge_metrics

header = generate_header(models_dict)

# %% [markdown]
# ## 実験

# %%
import os
import pandas as pd

def _done_iterations(csv_path: str) -> set[int]:
    """既存CSVに記録済みのIteration(seed)を集合で返す。CSVが無ければ空集合。"""
    if not os.path.exists(csv_path):
        return set()
    try:
        # 列名の揺れに強くする（Iteration / iteration など）
        df = pd.read_csv(csv_path)
        col = None
        for c in df.columns:
            if c.strip().lower() == "iteration":
                col = c
                break
        if col is None:
            return set()
        return set(pd.to_numeric(df[col], errors="coerce").dropna().astype(int).tolist())
    except Exception:
        return set()

# %%
from synthetic_data.split_data import split_balanced_data
from src.data.generate import dependency_matrix
from src.utils.metrics import evaluate_distributions, evaluate_test

# パラメータを変化させて実験
for i, config in enumerate(configs):
    print(f"Experiment {i+1}/{len(configs)}: {config}")

    # このconfigに対応するCSVパスを先に決めておく（スキップ判定に使う）
    csv_path = (
        f'./results/simulation_results_{config["n_students"]}_{config["n_skills"]}_'
        f'{config["smoothing"]}_{config["alpha"]}_{config["beta"]}_'
        f'{config["growth_alpha"]}_{config["growth_beta"]}.csv'
    )
    done = _done_iterations(csv_path)

    for pattern in range(args.n_experiments):
        seed = pattern

        # --- 既にこのseedの結果がCSVにあればスキップ ---
        if pattern in done:
            print(f"[SKIP] config={i} seed={pattern} は既存CSVにあり: {csv_path}")
            continue

        set_seed(seed)
        A = dependency_matrix(config["n_skills"])

        # 学習データ生成
        dataset, dataset_all, dataset2 = generate_data(A, config)

        # proposedモデル
        print("Proposed Model")
        set_seed(seed)
        X_train, y_train, X_val, y_val = split_balanced_data(dataset, args.split_ratio, device=device)
        model = Model(config["n_skills"]).to(device)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=args.lr)
        t_loss, v_loss = train_model(args, model, X_train, y_train, X_val, y_val, criterion, optimizer, seed, "proposed_model", config, device)
        models_dict["proposed"] = model

        # 上限モデル
        print("Upper Model")
        set_seed(seed)
        upper_data = np.concatenate([dataset, dataset2], axis=0)
        upper_X_train_X, upper_X_train_Y, upper_X_val_X, upper_X_val_Y = split_balanced_data(upper_data, args.split_ratio, device=device)
        upper_model = Model(config["n_skills"]).to(device)
        upper_criterion = nn.MSELoss()
        upper_optimizer = optim.Adam(upper_model.parameters(), lr=args.lr)
        upper_t_loss, upper_v_loss = train_model(args, upper_model, upper_X_train_X, upper_X_train_Y, upper_X_val_X, upper_X_val_Y, upper_criterion, upper_optimizer, seed, "upper_model", config, device)
        models_dict["upper"] = upper_model

        # allモデル
        print("All Model")
        set_seed(seed)
        all_X_train, all_y_train, all_X_val, all_y_val = split_balanced_data(dataset_all, args.split_ratio, device=device)
        all_model = Model(config["n_skills"]).to(device)
        all_criterion = nn.MSELoss()
        all_optimizer = optim.Adam(all_model.parameters(), lr=args.lr)
        all_t_loss, all_v_loss = train_model(args, all_model, all_X_train, all_y_train, all_X_val, all_y_val, all_criterion, all_optimizer, seed, "all_model", config, device)
        models_dict["all"] = all_model

        # テスト生成・評価
        _, _, test_dataset = generate_data(A, config, n_test=100)
        test_results = evaluate_test(models_dict, dataset, test_dataset)
        distribution_results = evaluate_distributions(models_dict, A, dataset, config)

        merged = merge_metrics(test_results, distribution_results)
        header = generate_header(models_dict)

        # ここでcsv_pathは既に定義済み
        ensure_csv_header(csv_path, header)
        row = make_row(pattern, header, merged)
        append_row(csv_path, row)

        # 直ちに「完了seed」を更新（クラッシュ時の再実行でもスキップが効くように）
        done.add(pattern)
# Out:
# Experiment 1/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=0 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# [SKIP] config=0 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_2.5.csv
# Experiment 2/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=1 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# [SKIP] config=1 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_5.0.csv
# Experiment 3/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=2 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# [SKIP] config=2 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_5.0_2.5.csv
# Experiment 4/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=3 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# [SKIP] config=3 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_2.5_10.0.csv
# Experiment 5/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=4 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# [SKIP] config=4 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_2.5_10.0_2.5.csv
# Experiment 6/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=5 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# [SKIP] config=5 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_2.5.csv
# Experiment 7/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=6 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# [SKIP] config=6 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_5.0.csv
# Experiment 8/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=7 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# [SKIP] config=7 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_5.0_2.5.csv
# Experiment 9/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=8 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# [SKIP] config=8 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_2.5_10.0.csv
# Experiment 10/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=9 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# [SKIP] config=9 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_5.0_10.0_2.5.csv
# Experiment 11/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=10 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# [SKIP] config=10 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_2.5.csv
# Experiment 12/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=11 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# [SKIP] config=11 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_5.0.csv
# Experiment 13/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=12 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# [SKIP] config=12 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_5.0_2.5.csv
# Experiment 14/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=13 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# [SKIP] config=13 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_2.5_10.0.csv
# Experiment 15/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=14 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# [SKIP] config=14 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_5.0_2.5_10.0_2.5.csv
# Experiment 16/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=15 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# [SKIP] config=15 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_2.5.csv
# Experiment 17/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=16 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# [SKIP] config=16 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_5.0.csv
# Experiment 18/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=17 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# [SKIP] config=17 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_5.0_2.5.csv
# Experiment 19/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=18 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# [SKIP] config=18 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_2.5_10.0.csv
# Experiment 20/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=19 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# [SKIP] config=19 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_2.5_10.0_10.0_2.5.csv
# Experiment 21/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=20 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# [SKIP] config=20 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_2.5.csv
# Experiment 22/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=21 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# [SKIP] config=21 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_5.0.csv
# Experiment 23/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=22 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# [SKIP] config=22 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_5.0_2.5.csv
# Experiment 24/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=23 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# [SKIP] config=23 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_2.5_10.0.csv
# Experiment 25/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.1, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=24 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# [SKIP] config=24 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.1_10.0_2.5_10.0_2.5.csv
# Experiment 26/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=25 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# [SKIP] config=25 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_2.5.csv
# Experiment 27/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=26 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# [SKIP] config=26 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_5.0.csv
# Experiment 28/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=27 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# [SKIP] config=27 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_5.0_2.5.csv
# Experiment 29/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=28 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# [SKIP] config=28 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_2.5_10.0.csv
# Experiment 30/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 2.5, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=29 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# [SKIP] config=29 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_2.5_10.0_2.5.csv
# Experiment 31/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=30 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# [SKIP] config=30 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_2.5.csv
# Experiment 32/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=31 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# [SKIP] config=31 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_5.0.csv
# Experiment 33/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=32 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# [SKIP] config=32 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_5.0_2.5.csv
# Experiment 34/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=33 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# [SKIP] config=33 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_2.5_10.0.csv
# Experiment 35/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 5.0, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=34 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# [SKIP] config=34 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_5.0_10.0_2.5.csv
# Experiment 36/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=35 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# [SKIP] config=35 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_2.5.csv
# Experiment 37/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=36 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# [SKIP] config=36 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_5.0.csv
# Experiment 38/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=37 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# [SKIP] config=37 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_5.0_2.5.csv
# Experiment 39/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=38 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# [SKIP] config=38 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_2.5_10.0.csv
# Experiment 40/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 5.0, 'beta': 2.5, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=39 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# [SKIP] config=39 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_5.0_2.5_10.0_2.5.csv
# Experiment 41/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 2.5, 'growth_beta': 2.5}
# [SKIP] config=40 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# [SKIP] config=40 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_2.5.csv
# Experiment 42/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 2.5, 'growth_beta': 5.0}
# [SKIP] config=41 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# [SKIP] config=41 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_5.0.csv
# Experiment 43/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# [SKIP] config=42 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# [SKIP] config=42 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_5.0_2.5.csv
# Experiment 44/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# [SKIP] config=43 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=6 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=7 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=8 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# [SKIP] config=43 seed=9 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_2.5_10.0.csv
# Experiment 45/675: {'n_students': 50, 'n_skills': 5, 'smoothing': 0.3, 'alpha': 2.5, 'beta': 10.0, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# [SKIP] config=44 seed=0 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_10.0_2.5.csv
# [SKIP] config=44 seed=1 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_10.0_2.5.csv
# [SKIP] config=44 seed=2 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_10.0_2.5.csv
# [SKIP] config=44 seed=3 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_10.0_2.5.csv
# [SKIP] config=44 seed=4 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_10.0_2.5.csv
# [SKIP] config=44 seed=5 は既存CSVにあり: ./results/simulation_results_50_5_0.3_2.5_10.0_10.0_2.5.csv
# ...
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_all_model_6.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_proposed_model_7.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_upper_model_7.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_all_model_7.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_proposed_model_8.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_upper_model_8.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_all_model_8.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_proposed_model_9.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_upper_model_9.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_5.0_all_model_9.pt
# [Skip] Training skipped since model already exists.
# Experiment 673/675: {'n_students': 150, 'n_skills': 15, 'smoothing': 0.5, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 5.0, 'growth_beta': 2.5}
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_0.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_0.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_0.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_1.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_1.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_1.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_2.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_2.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_2.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_3.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_3.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_3.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_4.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_4.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_4.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_5.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_5.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_5.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_6.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_6.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_6.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_7.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_7.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_7.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_8.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_8.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_8.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_proposed_model_9.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_upper_model_9.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_5.0_2.5_all_model_9.pt
# [Skip] Training skipped since model already exists.
# Experiment 674/675: {'n_students': 150, 'n_skills': 15, 'smoothing': 0.5, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 2.5, 'growth_beta': 10.0}
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_0.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_0.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_0.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_1.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_1.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_1.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_2.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_2.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_2.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_3.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_3.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_3.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_4.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_4.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_4.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_5.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_5.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_5.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_6.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_6.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_6.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_7.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_7.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_7.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_8.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_8.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_8.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_proposed_model_9.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_upper_model_9.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_2.5_10.0_all_model_9.pt
# [Skip] Training skipped since model already exists.
# Experiment 675/675: {'n_students': 150, 'n_skills': 15, 'smoothing': 0.5, 'alpha': 10.0, 'beta': 2.5, 'growth_alpha': 10.0, 'growth_beta': 2.5}
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_0.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_0.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_0.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_1.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_1.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_1.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_2.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_2.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_2.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_3.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_3.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_3.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_4.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_4.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_4.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_5.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_5.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_5.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_6.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_6.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_6.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_7.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_7.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_7.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_8.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_8.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_8.pt
# [Skip] Training skipped since model already exists.
# Proposed Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_proposed_model_9.pt
# [Skip] Training skipped since model already exists.
# Upper Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_upper_model_9.pt
# [Skip] Training skipped since model already exists.
# All Model
# [Skip] Found existing model file: simu_model/150_15_0.5_10.0_2.5_10.0_2.5_all_model_9.pt
# [Skip] Training skipped since model already exists.
